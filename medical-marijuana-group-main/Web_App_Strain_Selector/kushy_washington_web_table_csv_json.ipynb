# %%
# Import dependencies
import pandas as pd

# %%
# Read in csv file as pandas dataframe
file_dir = 'C:/Users/jemis/Class_Master/Module_20/Data/'
kushy_washington_web_table_df = pd.read_csv(f'{file_dir}kushy_washington_web_table.csv')
kushy_washington_web_table_df.head()
# Out:
#           test_strain    type   ailment_1 effects_1 flavor_1  thc_max  \
# 0      Dutch Hawaiian  Sativa  Depression     Happy   Citrus  20.1309
# 1           SleeStack  Hybrid      Stress  Uplifted    Sweet   9.9139
# 2        Space Needle  Sativa  Depression  Uplifted     Pine  10.8132
# 3  Double Purple Doja  Hybrid        Pain   Relaxed   Earthy  11.6702
# 4    Jack Skellington  Hybrid      Stress  Creative   Citrus  13.4657
#
#    cbd_max  chemotype  strain_leafly_review_rank  strain_leafly_page_rank
# 0     0.54          1                        141                      619
# 1     0.00          1                        151                     1276
# 2     0.00          1                          0                        0
# 3     0.00          1                        151                     1115
# 4     0.00          1                        141                      708

# %%
# Convert csv file json
kushy_washington_web_table_df.to_json(f'{file_dir}kushy_washington_web_table.json', orient='records')
